# %% [markdown]
# ##Department Payroll Summary:

# %%
# %sql
SELECT department_name, location, total_monthly_payroll, avg_compensation 
FROM shivam_project.gold.dept_payroll_summary;

# %% [markdown]
# ##Headcount vs Budget:

# %%
# %sql
SELECT department_name, actual_headcount, head_count_budget, remaining_budget 
FROM shivam_project.gold.headcount_vs_budget;
